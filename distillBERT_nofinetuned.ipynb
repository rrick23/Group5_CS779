# %%
import numpy as np
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/semeval/SemEval2025/test.tsv
# /kaggle/input/semeval/SemEval2025/clip1.py
# /kaggle/input/semeval/SemEval2025/train.tsv
# /kaggle/input/semeval/SemEval2025/CS779-Project5-AdMIRe-MidTerm-Presentation-5.pdf
# /kaggle/input/semeval/SemEval2025/2022.csv
# /kaggle/input/semeval/SemEval2025/Subtask B/subtask_b_sample.tsv
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/15529605996.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/17543802828.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/s2_18056618867.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/14839290985.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/19106979831.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/s1_18703651931.png
# /kaggle/input/semeval/SemEval2025/Subtask B/new blood/13567540079.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/12588591958.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/s2_16640394825.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/13534451742.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/15041446467.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/s1_14680137216.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/14430159460.png
# /kaggle/input/semeval/SemEval2025/Subtask B/panda car/14841366419.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/18776729826.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/15396758929.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/s2_17481037329.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/13924425519.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/s1_14946360557.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/18936376555.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cold turkey/15225410403.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/17939428269.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/s1_17327426725.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/12857554015.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/15874324235.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/18589992711.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/11568316208.png
# /kaggle/input/semeval/SemEval2025/Subtask B/cutting edge/s2_16442795692.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/18830973787.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/16582064535.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/18313557341.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/12644618292.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/s1_12022430124.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/s2_14022378446.png
# /kaggle/input/semeval/SemEval2025/Subtask B/ancient history/14010802486.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/14491215570.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/17755453635.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/s1_12757615746.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/13430724965.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/18419494179.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/s2_11439850561.png
# /kaggle/input/semeval/SemEval2025/Subtask B/bad apple/13399455899.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/s1_15295172323.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/12170653129.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/14210038187.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/16357347121.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/17394687995.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/s2_18823123655.png
# /kaggle/input/semeval/SemEval2025/Subtask B/acid test/14259893859.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/11913026279.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/13995567667.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/13114550583.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/11890871185.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/s2_11694683444.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/s1_12533247337.png
# /kaggle/input/semeval/SemEval2025/Subtask B/agony aunt/16785309123.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/14091696555.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/12254066021.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/15036633795.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/s1_15434734562.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/13909526110.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/s2_16545220076.png
# /kaggle/input/semeval/SemEval2025/Subtask B/sour grapes/16093960675.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/s1_14286866228.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/16393761698.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/s2_14897527653.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/14991138469.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/17009919526.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/18074522566.png
# /kaggle/input/semeval/SemEval2025/Subtask B/guinea pig/12280316665.png
# /kaggle/input/semeval/SemEval2025/Ref/BLI_2.pdf
# /kaggle/input/semeval/SemEval2025/Ref/BERT.pdf
# /kaggle/input/semeval/SemEval2025/Ref/BLIP.pdf
# /kaggle/input/semeval/SemEval2025/Ref/CLIP.pdf
# /kaggle/input/semeval/SemEval2025/Ref/ALIGN.pdf
# /kaggle/input/semeval/SemEval2025/Ref/Attention.pdf
# /kaggle/input/semeval/SemEval2025/sample_data_a/subtask_a_sample.tsv
# /kaggle/input/semeval/SemEval2025/sample_data_a/cold turkey/14860231156.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/cold turkey/15775392234.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/cold turkey/12709933613.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/cold turkey/19332109445.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/cold turkey/19948917504.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/dog's dinner/18208189584.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/dog's dinner/14353943618.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/dog's dinner/12550947666.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/dog's dinner/16667540563.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/dog's dinner/16822813551.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/silver bullet/13902967431.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/silver bullet/13033318091.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/silver bullet/12746768332.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/silver bullet/16955725223.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/silver bullet/11469070592.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/flower child/12094761076.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/flower child/13214637204.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/flower child/15129878660.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/flower child/19889194385.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/flower child/16472175879.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/baby blues/17673149213.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/baby blues/15937423426.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/baby blues/18977558618.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/baby blues/12989714906.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/baby blues/15930729179.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/rat race/11806530878.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/rat race/19557274874.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/rat race/11214217474.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/rat race/19986779997.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/rat race/16541723778.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/bad apple/19750043137.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/bad apple/13628077630.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/bad apple/17974785804.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/bad apple/18891226545.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/bad apple/15600015786.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/acid test/13294919581.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/acid test/13206447996.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/acid test/18855266619.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/acid test/17245637000.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/acid test/18413619396.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/agony aunt/11589516470.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/agony aunt/17943281902.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/agony aunt/16895152729.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/agony aunt/18202108483.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/agony aunt/16524569412.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/guinea pig/19504908802.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/guinea pig/13691052706.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/guinea pig/19526796676.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/guinea pig/18438695752.png
# /kaggle/input/semeval/SemEval2025/sample_data_a/guinea pig/11763307700.png
# /kaggle/input/semeval/SemEval2025/train/subtask_a_train.tsv
# /kaggle/input/semeval/SemEval2025/train/pipedream/41486582831.png
# /kaggle/input/semeval/SemEval2025/train/pipedream/89899531949.png
# /kaggle/input/semeval/SemEval2025/train/pipedream/57336253001.png
# /kaggle/input/semeval/SemEval2025/train/pipedream/02795863019.png
# /kaggle/input/semeval/SemEval2025/train/pipedream/75172836336.png
# /kaggle/input/semeval/SemEval2025/train/low-hangingfruit/20825217491.png
# /kaggle/input/semeval/SemEval2025/train/low-hangingfruit/87359560017.png
# /kaggle/input/semeval/SemEval2025/train/low-hangingfruit/42866872474.png
# /kaggle/input/semeval/SemEval2025/train/low-hangingfruit/91117857131.png
# /kaggle/input/semeval/SemEval2025/train/low-hangingfruit/28404294077.png
# /kaggle/input/semeval/SemEval2025/train/donkeywork/18787432584.png
# /kaggle/input/semeval/SemEval2025/train/donkeywork/21236393136.png
# /kaggle/input/semeval/SemEval2025/train/donkeywork/06637246420.png
# /kaggle/input/semeval/SemEval2025/train/donkeywork/20662025964.png
# /kaggle/input/semeval/SemEval2025/train/donkeywork/18911527144.png
# /kaggle/input/semeval/SemEval2025/train/armchaircritic/66678388745.png
# /kaggle/input/semeval/SemEval2025/train/armchaircritic/22768920335.png
# /kaggle/input/semeval/SemEval2025/train/armchaircritic/36891525128.png
# /kaggle/input/semeval/SemEval2025/train/armchaircritic/67127914712.png
# /kaggle/input/semeval/SemEval2025/train/armchaircritic/27123744055.png
# /kaggle/input/semeval/SemEval2025/train/nestegg/61212005778.png
# /kaggle/input/semeval/SemEval2025/train/nestegg/18562114617.png
# /kaggle/input/semeval/SemEval2025/train/nestegg/62701169481.png
# /kaggle/input/semeval/SemEval2025/train/nestegg/23144357017.png
# /kaggle/input/semeval/SemEval2025/train/nestegg/02370420010.png
# /kaggle/input/semeval/SemEval2025/train/two-waystreet/83632254366.png
# /kaggle/input/semeval/SemEval2025/train/two-waystreet/70843122394.png
# /kaggle/input/semeval/SemEval2025/train/two-waystreet/02864043166.png
# /kaggle/input/semeval/SemEval2025/train/two-waystreet/77388092739.png
# /kaggle/input/semeval/SemEval2025/train/two-waystreet/64314348310.png
# /kaggle/input/semeval/SemEval2025/train/bananarepublic/14331448769.png
# /kaggle/input/semeval/SemEval2025/train/bananarepublic/42960735833.png
# /kaggle/input/semeval/SemEval2025/train/bananarepublic/54445954523.png
# /kaggle/input/semeval/SemEval2025/train/bananarepublic/09384622843.png
# /kaggle/input/semeval/SemEval2025/train/bananarepublic/59540059198.png
# /kaggle/input/semeval/SemEval2025/train/dirtymoney/46913780614.png
# /kaggle/input/semeval/SemEval2025/train/dirtymoney/24738184590.png
# /kaggle/input/semeval/SemEval2025/train/dirtymoney/62777714452.png
# /kaggle/input/semeval/SemEval2025/train/dirtymoney/08230960409.png
# /kaggle/input/semeval/SemEval2025/train/dirtymoney/58491774071.png
# /kaggle/input/semeval/SemEval2025/train/ratrun/87303309822.png
# /kaggle/input/semeval/SemEval2025/train/ratrun/60896460729.png
# /kaggle/input/semeval/SemEval2025/train/ratrun/32737581165.png
# /kaggle/input/semeval/SemEval2025/train/ratrun/55855203654.png
# /kaggle/input/semeval/SemEval2025/train/ratrun/94938520064.png
# /kaggle/input/semeval/SemEval2025/train/redflag/59390351123.png
# /kaggle/input/semeval/SemEval2025/train/redflag/63105721515.png
# /kaggle/input/semeval/SemEval2025/train/redflag/31173191426.png
# /kaggle/input/semeval/SemEval2025/train/redflag/88424293285.png
# /kaggle/input/semeval/SemEval2025/train/redflag/49339545808.png
# /kaggle/input/semeval/SemEval2025/train/bunintheoven/24126898562.png
# /kaggle/input/semeval/SemEval2025/train/bunintheoven/69447699784.png
# /kaggle/input/semeval/SemEval2025/train/bunintheoven/50796495623.png
# /kaggle/input/semeval/SemEval2025/train/bunintheoven/64309391652.png
# /kaggle/input/semeval/SemEval2025/train/bunintheoven/68092803556.png
# /kaggle/input/semeval/SemEval2025/train/loungelizard/98466676612.png
# /kaggle/input/semeval/SemEval2025/train/loungelizard/90408626150.png
# /kaggle/input/semeval/SemEval2025/train/loungelizard/71941017088.png
# /kaggle/input/semeval/SemEval2025/train/loungelizard/89810040757.png
# /kaggle/input/semeval/SemEval2025/train/loungelizard/60914711661.png
# /kaggle/input/semeval/SemEval2025/train/ivorytower/19861926689.png
# /kaggle/input/semeval/SemEval2025/train/ivorytower/39323799209.png
# /kaggle/input/semeval/SemEval2025/train/ivorytower/45153820818.png
# /kaggle/input/semeval/SemEval2025/train/ivorytower/09597167816.png
# /kaggle/input/semeval/SemEval2025/train/ivorytower/05445068868.png
# /kaggle/input/semeval/SemEval2025/train/privateeye/95762945875.png
# /kaggle/input/semeval/SemEval2025/train/privateeye/66264001169.png
# /kaggle/input/semeval/SemEval2025/train/privateeye/37448041335.png
# /kaggle/input/semeval/SemEval2025/train/privateeye/42541218123.png
# /kaggle/input/semeval/SemEval2025/train/privateeye/86990947307.png
# /kaggle/input/semeval/SemEval2025/train/nightowl/89375227504.png
# /kaggle/input/semeval/SemEval2025/train/nightowl/61697797701.png
# /kaggle/input/semeval/SemEval2025/train/nightowl/00982495584.png
# /kaggle/input/semeval/SemEval2025/train/nightowl/93189810779.png
# /kaggle/input/semeval/SemEval2025/train/nightowl/93541983868.png
# /kaggle/input/semeval/SemEval2025/train/springchicken/66116309434.png
# /kaggle/input/semeval/SemEval2025/train/springchicken/76118640398.png
# /kaggle/input/semeval/SemEval2025/train/springchicken/57301692989.png
# /kaggle/input/semeval/SemEval2025/train/springchicken/81474137778.png
# /kaggle/input/semeval/SemEval2025/train/springchicken/20324325790.png
# /kaggle/input/semeval/SemEval2025/train/heartofgold/54240592941.png
# /kaggle/input/semeval/SemEval2025/train/heartofgold/86137977215.png
# /kaggle/input/semeval/SemEval2025/train/heartofgold/78062290185.png
# /kaggle/input/semeval/SemEval2025/train/heartofgold/90660547751.png
# /kaggle/input/semeval/SemEval2025/train/heartofgold/92088849364.png
# /kaggle/input/semeval/SemEval2025/train/applesandoranges/34972099351.png
# /kaggle/input/semeval/SemEval2025/train/applesandoranges/78981196177.png
# /kaggle/input/semeval/SemEval2025/train/applesandoranges/06670601370.png
# /kaggle/input/semeval/SemEval2025/train/applesandoranges/06706738051.png
# /kaggle/input/semeval/SemEval2025/train/applesandoranges/47167686168.png
# /kaggle/input/semeval/SemEval2025/train/devilsadvocate/77995675587.png
# /kaggle/input/semeval/SemEval2025/train/devilsadvocate/45875492932.png
# /kaggle/input/semeval/SemEval2025/train/devilsadvocate/11847407637.png
# /kaggle/input/semeval/SemEval2025/train/devilsadvocate/95645261777.png
# /kaggle/input/semeval/SemEval2025/train/devilsadvocate/86883605636.png
# /kaggle/input/semeval/SemEval2025/train/wetblanket/03496279195.png
# /kaggle/input/semeval/SemEval2025/train/wetblanket/64522104806.png
# /kaggle/input/semeval/SemEval2025/train/wetblanket/88635314726.png
# /kaggle/input/semeval/SemEval2025/train/wetblanket/39385479814.png
# /kaggle/input/semeval/SemEval2025/train/wetblanket/28147683669.png
# /kaggle/input/semeval/SemEval2025/train/busybee/33246843335.png
# /kaggle/input/semeval/SemEval2025/train/busybee/27532602036.png
# /kaggle/input/semeval/SemEval2025/train/busybee/50206720330.png
# /kaggle/input/semeval/SemEval2025/train/busybee/50516840411.png
# /kaggle/input/semeval/SemEval2025/train/busybee/13914680332.png
# /kaggle/input/semeval/SemEval2025/train/hotpotato/20231777670.png
# /kaggle/input/semeval/SemEval2025/train/hotpotato/84435539379.png
# /kaggle/input/semeval/SemEval2025/train/hotpotato/95656943243.png
# /kaggle/input/semeval/SemEval2025/train/hotpotato/31362616456.png
# /kaggle/input/semeval/SemEval2025/train/hotpotato/73009108593.png
# /kaggle/input/semeval/SemEval2025/train/secretsanta/43012219877.png
# /kaggle/input/semeval/SemEval2025/train/secretsanta/43315095878.png
# /kaggle/input/semeval/SemEval2025/train/secretsanta/83896740010.png
# /kaggle/input/semeval/SemEval2025/train/secretsanta/53937857464.png
# /kaggle/input/semeval/SemEval2025/train/secretsanta/73884284579.png
# /kaggle/input/semeval/SemEval2025/train/guineapig/20717384670.png
# /kaggle/input/semeval/SemEval2025/train/guineapig/66149700285.png
# /kaggle/input/semeval/SemEval2025/train/guineapig/14575503360.png
# /kaggle/input/semeval/SemEval2025/train/guineapig/37944668726.png
# /kaggle/input/semeval/SemEval2025/train/guineapig/05733696351.png
# /kaggle/input/semeval/SemEval2025/train/bullmarket/02072099056.png
# /kaggle/input/semeval/SemEval2025/train/bullmarket/52868171709.png
# /kaggle/input/semeval/SemEval2025/train/bullmarket/32267606120.png
# /kaggle/input/semeval/SemEval2025/train/bullmarket/55188636806.png
# /kaggle/input/semeval/SemEval2025/train/bullmarket/16206684278.png
# /kaggle/input/semeval/SemEval2025/train/painintheneck/59520456167.png
# /kaggle/input/semeval/SemEval2025/train/painintheneck/06915129382.png
# /kaggle/input/semeval/SemEval2025/train/painintheneck/99595459963.png
# /kaggle/input/semeval/SemEval2025/train/painintheneck/08190047042.png
# /kaggle/input/semeval/SemEval2025/train/painintheneck/86378892255.png
# /kaggle/input/semeval/SemEval2025/train/honeytrap/66042334676.png
# /kaggle/input/semeval/SemEval2025/train/honeytrap/37674249712.png
# /kaggle/input/semeval/SemEval2025/train/honeytrap/39822764653.png
# /kaggle/input/semeval/SemEval2025/train/honeytrap/13606752629.png
# /kaggle/input/semeval/SemEval2025/train/honeytrap/35168957863.png
# /kaggle/input/semeval/SemEval2025/train/elbowgrease/35234427395.png
# /kaggle/input/semeval/SemEval2025/train/elbowgrease/74852536462.png
# /kaggle/input/semeval/SemEval2025/train/elbowgrease/39938261459.png
# /kaggle/input/semeval/SemEval2025/train/elbowgrease/54879908369.png
# /kaggle/input/semeval/SemEval2025/train/elbowgrease/53378381715.png
# /kaggle/input/semeval/SemEval2025/train/brainsurgery/00389092717.png
# /kaggle/input/semeval/SemEval2025/train/brainsurgery/20059340578.png
# /kaggle/input/semeval/SemEval2025/train/brainsurgery/14221797226.png
# /kaggle/input/semeval/SemEval2025/train/brainsurgery/14803973068.png
# /kaggle/input/semeval/SemEval2025/train/brainsurgery/77652241695.png
# /kaggle/input/semeval/SemEval2025/train/pinsandneedles/18951355308.png
# /kaggle/input/semeval/SemEval2025/train/pinsandneedles/24771463968.png
# /kaggle/input/semeval/SemEval2025/train/pinsandneedles/31343098424.png
# /kaggle/input/semeval/SemEval2025/train/pinsandneedles/69262707128.png
# /kaggle/input/semeval/SemEval2025/train/pinsandneedles/62351469038.png
# /kaggle/input/semeval/SemEval2025/train/coldturkey/78631376435.png
# /kaggle/input/semeval/SemEval2025/train/coldturkey/16239351344.png
# /kaggle/input/semeval/SemEval2025/train/coldturkey/53986444390.png
# /kaggle/input/semeval/SemEval2025/train/coldturkey/65148693634.png
# /kaggle/input/semeval/SemEval2025/train/coldturkey/47545447824.png
# /kaggle/input/semeval/SemEval2025/train/badapple/78200848882.png
# /kaggle/input/semeval/SemEval2025/train/badapple/82053252112.png
# /kaggle/input/semeval/SemEval2025/train/badapple/87462057419.png
# /kaggle/input/semeval/SemEval2025/train/badapple/43074669652.png
# /kaggle/input/semeval/SemEval2025/train/badapple/39242366111.png
# /kaggle/input/semeval/SemEval2025/train/shrinkingviolet/97482048489.png
# /kaggle/input/semeval/SemEval2025/train/shrinkingviolet/68016869942.png
# /kaggle/input/semeval/SemEval2025/train/shrinkingviolet/45394842176.png
# /kaggle/input/semeval/SemEval2025/train/shrinkingviolet/77861539717.png
# /kaggle/input/semeval/SemEval2025/train/shrinkingviolet/11844321898.png
# /kaggle/input/semeval/SemEval2025/train/pieceofcake/78485019666.png
# /kaggle/input/semeval/SemEval2025/train/pieceofcake/84842839046.png
# /kaggle/input/semeval/SemEval2025/train/pieceofcake/55124577858.png
# /kaggle/input/semeval/SemEval2025/train/pieceofcake/96911519929.png
# /kaggle/input/semeval/SemEval2025/train/pieceofcake/04237996522.png
# /kaggle/input/semeval/SemEval2025/train/beachedwhale/29988565894.png
# /kaggle/input/semeval/SemEval2025/train/beachedwhale/37685710911.png
# /kaggle/input/semeval/SemEval2025/train/beachedwhale/67110850257.png
# /kaggle/input/semeval/SemEval2025/train/beachedwhale/10430203037.png
# /kaggle/input/semeval/SemEval2025/train/beachedwhale/44697847461.png
# /kaggle/input/semeval/SemEval2025/train/topdog/43207170783.png
# /kaggle/input/semeval/SemEval2025/train/topdog/76177115752.png
# /kaggle/input/semeval/SemEval2025/train/topdog/44297130521.png
# /kaggle/input/semeval/SemEval2025/train/topdog/62040589986.png
# /kaggle/input/semeval/SemEval2025/train/topdog/38568900802.png
# /kaggle/input/semeval/SemEval2025/train/agonyaunt/57658144685.png
# /kaggle/input/semeval/SemEval2025/train/agonyaunt/83600499282.png
# /kaggle/input/semeval/SemEval2025/train/agonyaunt/92533456778.png
# /kaggle/input/semeval/SemEval2025/train/agonyaunt/32964421720.png
# /kaggle/input/semeval/SemEval2025/train/agonyaunt/02512838127.png
# /kaggle/input/semeval/SemEval2025/train/dirtyword/14069763077.png
# /kaggle/input/semeval/SemEval2025/train/dirtyword/36466202137.png
# /kaggle/input/semeval/SemEval2025/train/dirtyword/24899523859.png
# /kaggle/input/semeval/SemEval2025/train/dirtyword/06993539786.png
# /kaggle/input/semeval/SemEval2025/train/dirtyword/44754936991.png
# /kaggle/input/semeval/SemEval2025/train/brassring/96956947028.png
# /kaggle/input/semeval/SemEval2025/train/brassring/80706529304.png
# /kaggle/input/semeval/SemEval2025/train/brassring/95672336968.png
# /kaggle/input/semeval/SemEval2025/train/brassring/65189326623.png
# /kaggle/input/semeval/SemEval2025/train/brassring/51003386336.png
# /kaggle/input/semeval/SemEval2025/train/whiteelephant/81445236099.png
# /kaggle/input/semeval/SemEval2025/train/whiteelephant/14504224870.png
# /kaggle/input/semeval/SemEval2025/train/whiteelephant/25156360931.png
# /kaggle/input/semeval/SemEval2025/train/whiteelephant/95221758898.png
# /kaggle/input/semeval/SemEval2025/train/whiteelephant/61362577917.png
# /kaggle/input/semeval/SemEval2025/train/rocketscience/66888109136.png
# /kaggle/input/semeval/SemEval2025/train/rocketscience/83472329575.png
# /kaggle/input/semeval/SemEval2025/train/rocketscience/61309592117.png
# /kaggle/input/semeval/SemEval2025/train/rocketscience/05490541317.png
# /kaggle/input/semeval/SemEval2025/train/rocketscience/89043407312.png
# /kaggle/input/semeval/SemEval2025/train/loanshark/32211216966.png
# /kaggle/input/semeval/SemEval2025/train/loanshark/72575235835.png
# /kaggle/input/semeval/SemEval2025/train/loanshark/36582309103.png
# /kaggle/input/semeval/SemEval2025/train/loanshark/91154880140.png
# /kaggle/input/semeval/SemEval2025/train/loanshark/57469910132.png
# /kaggle/input/semeval/SemEval2025/train/catseyes/97172825746.png
# /kaggle/input/semeval/SemEval2025/train/catseyes/40926790413.png
# /kaggle/input/semeval/SemEval2025/train/catseyes/07373156187.png
# /kaggle/input/semeval/SemEval2025/train/catseyes/89307973022.png
# /kaggle/input/semeval/SemEval2025/train/catseyes/22025540184.png
# /kaggle/input/semeval/SemEval2025/train/zebracrossing/58091284576.png
# /kaggle/input/semeval/SemEval2025/train/zebracrossing/24926483896.png
# /kaggle/input/semeval/SemEval2025/train/zebracrossing/69410806712.png
# /kaggle/input/semeval/SemEval2025/train/zebracrossing/62775742958.png
# /kaggle/input/semeval/SemEval2025/train/zebracrossing/50338175575.png
# /kaggle/input/semeval/SemEval2025/train/ghosttown/08510094453.png
# /kaggle/input/semeval/SemEval2025/train/ghosttown/77229322693.png
# /kaggle/input/semeval/SemEval2025/train/ghosttown/96149834283.png
# /kaggle/input/semeval/SemEval2025/train/ghosttown/95676628446.png
# /kaggle/input/semeval/SemEval2025/train/ghosttown/81343436490.png
# /kaggle/input/semeval/SemEval2025/train/graveyardshift/50809642929.png
# /kaggle/input/semeval/SemEval2025/train/graveyardshift/83947965924.png
# /kaggle/input/semeval/SemEval2025/train/graveyardshift/39559921078.png
# /kaggle/input/semeval/SemEval2025/train/graveyardshift/50466267708.png
# /kaggle/input/semeval/SemEval2025/train/graveyardshift/11712779940.png
# /kaggle/input/semeval/SemEval2025/train/ratrace/28647406758.png
# /kaggle/input/semeval/SemEval2025/train/ratrace/27816548474.png
# /kaggle/input/semeval/SemEval2025/train/ratrace/97737199528.png
# /kaggle/input/semeval/SemEval2025/train/ratrace/04209106095.png
# /kaggle/input/semeval/SemEval2025/train/ratrace/45504234188.png
# /kaggle/input/semeval/SemEval2025/train/blacksheep/40244159873.png
# /kaggle/input/semeval/SemEval2025/train/blacksheep/85414168973.png
# /kaggle/input/semeval/SemEval2025/train/blacksheep/80118206373.png
# /kaggle/input/semeval/SemEval2025/train/blacksheep/52872475612.png
# /kaggle/input/semeval/SemEval2025/train/blacksheep/94022502719.png
# /kaggle/input/semeval/SemEval2025/train/acidtest/03133054749.png
# /kaggle/input/semeval/SemEval2025/train/acidtest/38840705602.png
# /kaggle/input/semeval/SemEval2025/train/acidtest/76398012989.png
# /kaggle/input/semeval/SemEval2025/train/acidtest/02817176209.png
# /kaggle/input/semeval/SemEval2025/train/acidtest/45105971201.png
# /kaggle/input/semeval/SemEval2025/train/innercircle/32590417205.png
# /kaggle/input/semeval/SemEval2025/train/innercircle/69620536561.png
# /kaggle/input/semeval/SemEval2025/train/innercircle/60203367715.png
# /kaggle/input/semeval/SemEval2025/train/innercircle/74028690231.png
# /kaggle/input/semeval/SemEval2025/train/innercircle/34506090318.png
# /kaggle/input/semeval/SemEval2025/train/oldflame/47140387353.png
# /kaggle/input/semeval/SemEval2025/train/oldflame/31217316388.png
# /kaggle/input/semeval/SemEval2025/train/oldflame/35771360108.png
# /kaggle/input/semeval/SemEval2025/train/oldflame/17267051988.png
# /kaggle/input/semeval/SemEval2025/train/oldflame/06168811595.png
# /kaggle/input/semeval/SemEval2025/train/openbook/64138598987.png
# /kaggle/input/semeval/SemEval2025/train/openbook/59859593427.png
# /kaggle/input/semeval/SemEval2025/train/openbook/58632881432.png
# /kaggle/input/semeval/SemEval2025/train/openbook/06126366716.png
# /kaggle/input/semeval/SemEval2025/train/openbook/34251825412.png
# /kaggle/input/semeval/SemEval2025/train/lovetriangle/66352366466.png
# /kaggle/input/semeval/SemEval2025/train/lovetriangle/16857080306.png
# /kaggle/input/semeval/SemEval2025/train/lovetriangle/70080592856.png
# /kaggle/input/semeval/SemEval2025/train/lovetriangle/56377316808.png
# /kaggle/input/semeval/SemEval2025/train/lovetriangle/59548334929.png
# /kaggle/input/semeval/SemEval2025/train/flowerchild/27113356190.png
# /kaggle/input/semeval/SemEval2025/train/flowerchild/31939147449.png
# /kaggle/input/semeval/SemEval2025/train/flowerchild/70564136759.png
# /kaggle/input/semeval/SemEval2025/train/flowerchild/71677279296.png
# /kaggle/input/semeval/SemEval2025/train/flowerchild/66547801519.png
# /kaggle/input/semeval/SemEval2025/train/chickenfeed/37795851361.png
# /kaggle/input/semeval/SemEval2025/train/chickenfeed/57390097066.png
# /kaggle/input/semeval/SemEval2025/train/chickenfeed/95410072019.png
# /kaggle/input/semeval/SemEval2025/train/chickenfeed/21271058237.png
# /kaggle/input/semeval/SemEval2025/train/chickenfeed/48528496115.png
# /kaggle/input/semeval/SemEval2025/train/ancienthistory/91744816929.png
# /kaggle/input/semeval/SemEval2025/train/ancienthistory/20677180119.png
# /kaggle/input/semeval/SemEval2025/train/ancienthistory/89162981347.png
# /kaggle/input/semeval/SemEval2025/train/ancienthistory/97760341223.png
# /kaggle/input/semeval/SemEval2025/train/ancienthistory/80235397834.png
# /kaggle/input/semeval/SemEval2025/train/henparty/64751387734.png
# /kaggle/input/semeval/SemEval2025/train/henparty/37074365923.png
# /kaggle/input/semeval/SemEval2025/train/henparty/14218153967.png
# /kaggle/input/semeval/SemEval2025/train/henparty/77119535961.png
# /kaggle/input/semeval/SemEval2025/train/henparty/16686328418.png
# /kaggle/input/semeval/SemEval2025/train/closeshave/61687169887.png
# /kaggle/input/semeval/SemEval2025/train/closeshave/89483662888.png
# /kaggle/input/semeval/SemEval2025/train/closeshave/15095694666.png
# /kaggle/input/semeval/SemEval2025/train/closeshave/55410405875.png
# /kaggle/input/semeval/SemEval2025/train/closeshave/36654367033.png
# /kaggle/input/semeval/SemEval2025/train/bearmarket/99596916072.png
# /kaggle/input/semeval/SemEval2025/train/bearmarket/34535041645.png
# /kaggle/input/semeval/SemEval2025/train/bearmarket/81955291670.png
# /kaggle/input/semeval/SemEval2025/train/bearmarket/41056104334.png
# /kaggle/input/semeval/SemEval2025/train/bearmarket/81444958673.png
# /kaggle/input/semeval/SemEval2025/train/dogsdinner/26296913805.png
# /kaggle/input/semeval/SemEval2025/train/dogsdinner/69872042441.png
# /kaggle/input/semeval/SemEval2025/train/dogsdinner/25221168152.png
# /kaggle/input/semeval/SemEval2025/train/dogsdinner/47446416377.png
# /kaggle/input/semeval/SemEval2025/train/dogsdinner/43893542130.png
# /kaggle/input/semeval/SemEval2025/train/smokinggun/57957044165.png
# /kaggle/input/semeval/SemEval2025/train/smokinggun/30396026278.png
# /kaggle/input/semeval/SemEval2025/train/smokinggun/58880185181.png
# /kaggle/input/semeval/SemEval2025/train/smokinggun/32526851715.png
# /kaggle/input/semeval/SemEval2025/train/smokinggun/22927734727.png
# /kaggle/input/semeval/SemEval2025/train/blackbox/73920583487.png
# /kaggle/input/semeval/SemEval2025/train/blackbox/82295944756.png
# /kaggle/input/semeval/SemEval2025/train/blackbox/60904898706.png
# /kaggle/input/semeval/SemEval2025/train/blackbox/41077897719.png
# /kaggle/input/semeval/SemEval2025/train/blackbox/76956198734.png
# /kaggle/input/semeval/SemEval2025/train/silverbullet/14577105224.png
# /kaggle/input/semeval/SemEval2025/train/silverbullet/87765926961.png
# /kaggle/input/semeval/SemEval2025/train/silverbullet/44193989525.png
# /kaggle/input/semeval/SemEval2025/train/silverbullet/42403978271.png
# /kaggle/input/semeval/SemEval2025/train/silverbullet/48187131860.png
# /kaggle/input/semeval/SemEval2025/train/whitehat/12124292214.png
# /kaggle/input/semeval/SemEval2025/train/whitehat/13755461305.png
# /kaggle/input/semeval/SemEval2025/train/whitehat/39481587509.png
# /kaggle/input/semeval/SemEval2025/train/whitehat/11696820520.png
# /kaggle/input/semeval/SemEval2025/train/whitehat/50305046415.png
# /kaggle/input/semeval/SemEval2025/train/eyecandy/74941070286.png
# /kaggle/input/semeval/SemEval2025/train/eyecandy/00230957504.png
# /kaggle/input/semeval/SemEval2025/train/eyecandy/67393713269.png
# /kaggle/input/semeval/SemEval2025/train/eyecandy/77288299313.png
# /kaggle/input/semeval/SemEval2025/train/eyecandy/33933826748.png
# /kaggle/input/semeval/SemEval2025/train/babyblues/46456209569.png
# /kaggle/input/semeval/SemEval2025/train/babyblues/60185641466.png
# /kaggle/input/semeval/SemEval2025/train/babyblues/04071685511.png
# /kaggle/input/semeval/SemEval2025/train/babyblues/78529931749.png
# /kaggle/input/semeval/SemEval2025/train/babyblues/91570497980.png
# /kaggle/input/semeval/SemEval2025/train/gravytrain/65362654761.png
# /kaggle/input/semeval/SemEval2025/train/gravytrain/57293389133.png
# /kaggle/input/semeval/SemEval2025/train/gravytrain/54540831700.png
# /kaggle/input/semeval/SemEval2025/train/gravytrain/65809438894.png
# /kaggle/input/semeval/SemEval2025/train/gravytrain/98011817158.png
# /kaggle/input/semeval/SemEval2025/train/copycat/24801323866.png
# /kaggle/input/semeval/SemEval2025/train/copycat/82991780025.png
# /kaggle/input/semeval/SemEval2025/train/copycat/76230045663.png
# /kaggle/input/semeval/SemEval2025/train/copycat/39497588644.png
# /kaggle/input/semeval/SemEval2025/train/copycat/82047847966.png
# /kaggle/input/semeval/SemEval2025/train/highlife/49177713448.png
# /kaggle/input/semeval/SemEval2025/train/highlife/39122642061.png
# /kaggle/input/semeval/SemEval2025/train/highlife/40542311053.png
# /kaggle/input/semeval/SemEval2025/train/highlife/49516114391.png
# /kaggle/input/semeval/SemEval2025/train/highlife/06164272353.png
# /kaggle/input/semeval/SemEval2025/train/greenfingers/92628846416.png
# /kaggle/input/semeval/SemEval2025/train/greenfingers/10027562830.png
# /kaggle/input/semeval/SemEval2025/train/greenfingers/88406435457.png
# /kaggle/input/semeval/SemEval2025/train/greenfingers/38213294711.png
# /kaggle/input/semeval/SemEval2025/train/greenfingers/88683770392.png

# %%
import pandas as pd
import torch
from torch import nn, optim
from transformers import DistilBertModel, DistilBertTokenizer
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm


class ContrastiveDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len=128):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        sent1, sent2, sim = row['sentence_1'], row['sentence_2'], row['sim']
        sim = 1 if sim == 1 else 0

        encoded1 = self.tokenizer(
            sent1,
            max_length=self.max_len,
            truncation=True,
            padding="max_length",
            return_tensors="pt"
        )
        encoded2 = self.tokenizer(
            sent2,
            max_length=self.max_len,
            truncation=True,
            padding="max_length",
            return_tensors="pt"
        )
        
        return (
            encoded1['input_ids'].squeeze(0),
            encoded1['attention_mask'].squeeze(0),
            encoded2['input_ids'].squeeze(0),
            encoded2['attention_mask'].squeeze(0),
            torch.tensor(sim, dtype=torch.float32)
        )


class ContrastiveLoss(nn.Module):
    def __init__(self, margin=1.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin
        self.cosine_similarity = nn.CosineSimilarity(dim=1)

    def forward(self, output1, output2, label):
        similarity = self.cosine_similarity(output1, output2)
        pos_loss = label * torch.exp(-similarity)
        neg_loss = (1 - label) * torch.exp(similarity - self.margin)
        return torch.mean(pos_loss + neg_loss)


sep_token = "[SEP]"

def insert_sep_inside_sentence(sentence, compound):
    if compound in sentence:
        return sentence.replace(compound, f"{sep_token} {compound} {sep_token}")
    return sentence


def train_model(model, dataloader, optimizer, loss_fn, device, epochs=5, save_path="distilbert_model.bin"):
    model.train()
    model.to(device)

    for epoch in range(epochs):
        total_loss = 0
        for batch in tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}"):
            input_ids1, attention_mask1, input_ids2, attention_mask2, labels = [b.to(device) for b in batch]
            outputs1 = model(input_ids1, attention_mask=attention_mask1).last_hidden_state[:, 0, :]
            outputs2 = model(input_ids2, attention_mask=attention_mask2).last_hidden_state[:, 0, :]
            loss = loss_fn(outputs1, outputs2, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}")
        torch.save(model.state_dict(), f"{save_path}_epoch_{epoch+1}.bin")
    torch.save(model.state_dict(), save_path)
    print(f"Model saved to {save_path}")


def main():
    df = pd.read_csv('/kaggle/input/semeval/SemEval2025/2022.csv')
    df['sentence_1'] = df.apply(lambda row: insert_sep_inside_sentence(row['sentence_1'], row['MWE1']), axis=1)
    model = DistilBertModel.from_pretrained("distilbert-base-uncased")
    tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
    dataset = ContrastiveDataset(df, tokenizer)
    dataloader = DataLoader(dataset, batch_size=16, shuffle=True)
    loss_fn = ContrastiveLoss(margin=1.0)
    optimizer = optim.AdamW(model.parameters(), lr=5e-5)
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    save_path = "distilbert_model_contrastive.bin"
    train_model(model, dataloader, optimizer, loss_fn, device, epochs=10, save_path=save_path)

if __name__ == "__main__":
    main()
# Out:
# Epoch 1/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 1/10, Loss: 0.5155
# Epoch 2/10: 100%|██████████| 411/411 [01:28<00:00,  4.66it/s]
# Epoch 2/10, Loss: 0.3909
# Epoch 3/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 3/10, Loss: 0.3518
# Epoch 4/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 4/10, Loss: 0.3321
# Epoch 5/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 5/10, Loss: 0.3246
# Epoch 6/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 6/10, Loss: 0.3158
# Epoch 7/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 7/10, Loss: 0.3127
# Epoch 8/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 8/10, Loss: 0.3142
# Epoch 9/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 9/10, Loss: 0.3053
# Epoch 10/10: 100%|██████████| 411/411 [01:28<00:00,  4.67it/s]
# Epoch 10/10, Loss: 0.2998
# Model saved to distilbert_model_contrastive.bin

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import CLIPProcessor, CLIPModel, DistilBertTokenizer, DistilBertModel
from PIL import Image
import pandas as pd
import os
from tqdm import tqdm

image_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
text_model = DistilBertModel.from_pretrained("distilbert-base-uncased") 
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

##save_path = "distilbert_model_contrastive.bin"  
##text_model.load_state_dict(torch.load(save_path, map_location="cpu")) 
##print(f"Loaded trained text model from {save_path}")


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
image_model.to(device)
text_model.to(device)


image_embedding_reduction = nn.Linear(768, 512).to(device)  

text_embedding_reduction = nn.Linear(768, 512).to(device)

class ImageTextDataset(Dataset):
    def __init__(self, sentences, image_paths, processor, tokenizer, max_len=77):
        self.sentences = sentences
        self.image_paths = image_paths
        self.processor = processor
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        text = self.sentences[idx]
        image_paths = self.image_paths[5 * idx: 5 * idx + 5]  
        images = [Image.open(path).convert("RGB") for path in image_paths]
        
        encoded_text = self.tokenizer(text, max_length=self.max_len, truncation=True, padding="max_length", return_tensors="pt")
     
        image_inputs = self.processor(images=images, return_tensors="pt", padding=True)
       
        return encoded_text, image_inputs

class PlackettLuceLoss(nn.Module):
    def __init__(self):
        super(PlackettLuceLoss, self).__init__()

    def forward(self, scores, true_order):
        """
        Computes the Plackett-Luce loss.

        Args:
        - scores: Tensor of shape (batch_size, num_items), predicted scores for each item.
        - true_order: Tensor of shape (batch_size, num_items), true rankings or order.

        Returns:
        - loss: Scalar loss value.
        """
        loss = 0
        for batch_idx in range(scores.size(0)):
            current_scores = scores[batch_idx]
            current_order = true_order[batch_idx]

            # Sort scores and corresponding ground truth
            sorted_scores = current_scores[current_order]
            total_prob = 0

            for rank, score in enumerate(sorted_scores):
                numerator = torch.exp(score)
                denominator = torch.sum(torch.exp(sorted_scores[rank:]))
                total_prob += torch.log(numerator / denominator)

            loss -= total_prob

        return loss / scores.size(0)

df = pd.read_csv('/kaggle/input/semeval/SemEval2025/train.tsv', sep="\t")
ipath = []
sentences = []

for compound in df['compound']:
    ch = "".join(char for char in compound if char != " ")
    path = f'/kaggle/input/semeval/SemEval2025/train/{ch}'
    ipath.extend([os.path.join(path, img) for img in os.listdir(path) if img.endswith(".png")])

sentences.extend(df['sentence'])

dataset = ImageTextDataset(sentences, ipath, processor, tokenizer)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

pl_loss = PlackettLuceLoss()
optimizer = torch.optim.AdamW(list(image_model.parameters()) + list(text_model.parameters()), lr=2e-6)

epochs = 20
for epoch in range(epochs):
    image_model.train()
    text_model.train()
    total_loss = 0

    for batch in tqdm(dataloader, desc=f"Epoch {epoch+1}/{epochs}"):
       
        text_inputs, image_inputs = batch
        
      
        input_ids = text_inputs["input_ids"].squeeze(0).to(device) 
        attention_mask = text_inputs["attention_mask"].squeeze(0).to(device)
        
       
        pixel_values = image_inputs["pixel_values"].squeeze(0).to(device) 

        text_model.to(device)
        image_model.to(device)

        text_outputs = text_model(input_ids=input_ids, attention_mask=attention_mask)

        text_embeddings = text_outputs.last_hidden_state[:, 0, :]  
        text_embeddings = text_embeddings / text_embeddings.norm(dim=-1, keepdim=True)
        text_embeddings = text_embedding_reduction(text_embeddings) 
        text_embeddings = text_embeddings / text_embeddings.norm(dim=-1, keepdim=True)
        image_outputs = image_model.vision_model(pixel_values=pixel_values)
        image_embeddings = image_outputs[0]  
      
        image_embeddings = image_embeddings[:, 0, :]  
        image_embeddings = image_embeddings.to(device) 
     
        image_embeddings = image_embedding_reduction(image_embeddings)  
        image_embeddings = image_embeddings / image_embeddings.norm(dim=-1, keepdim=True)

       
        print(f"Text Embeddings Shape: {text_embeddings.shape}")
        print(f"Image Embeddings Shape: {image_embeddings.shape}")

       
        similarities = torch.matmul(text_embeddings, image_embeddings.T)  
        similarities = similarities.squeeze(0)  

        
        true_order = torch.argsort(similarities, descending=True)

   
        loss = pl_loss(similarities.unsqueeze(0), true_order.unsqueeze(0))
        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    avg_loss = total_loss / len(dataloader)
    print(f"Epoch {epoch+1}, Average Loss: {avg_loss:.4f}")

   
    torch.save(image_model.state_dict(), f"clip_image_model_epoch_{epoch+1}.bin")
    torch.save(text_model.state_dict(), f"distilbert_text_model_epoch_{epoch+1}.bin")

# %%
import torch
import os
from PIL import Image
from tqdm import tqdm
import pandas as pd
from transformers import DistilBertTokenizer
from transformers import CLIPProcessor, CLIPModel
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import CLIPProcessor, CLIPModel, DistilBertTokenizer, DistilBertModel

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

image_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
text_model = DistilBertModel.from_pretrained("distilbert-base-uncased").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

df2 = pd.read_csv('/kaggle/input/semeval/SemEval2025/test.tsv', sep="\t")

ipath2 = []
sentences2 = []

for i, row in df2.iterrows():
    compound = row['compound']
    expected_order = row['expected_order']
    ch = "".join(char for char in compound if char != " ")
    base_path = f'/kaggle/input/semeval/SemEval2025/train/{ch}'

    if os.path.exists(base_path):
        expected_order = expected_order.strip("[]").replace("'", "").split(",")
        for img_filename in expected_order:
            img_filename = img_filename.strip()
            full_path = os.path.join(base_path, img_filename)
            if os.path.isfile(full_path):
                ipath2.append(full_path)
    sentences2.append(row['sentence'])

def calculate_top1_and_top2_accuracy():
    image_model.eval()
    text_model.eval()

    correct_top1 = 0
    correct_top2 = 0
    total = 0
    text_projection_layer = torch.nn.Linear(768, 512).to(device)

    with torch.no_grad():
        for i, sentence in enumerate(tqdm(sentences2, desc="Evaluating on Test Data")):
            text_inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True).to(device)
            text_outputs = text_model(**text_inputs)
            text_embeddings = text_outputs.last_hidden_state[:, 0, :]
            text_embeddings = text_embeddings / text_embeddings.norm(dim=-1, keepdim=True)
            text_embeddings = text_projection_layer(text_embeddings)

            image_start_idx = 5 * i
            image_end_idx = image_start_idx + 4
            selected_image_paths = ipath2[image_start_idx:image_end_idx + 1]

            image_embeddings_list = []
            for path in selected_image_paths:
                image = Image.open(path).convert("RGB")
                pixel_values = processor(images=image, return_tensors="pt").pixel_values.to(device)
                image_embeddings = image_model.get_image_features(pixel_values=pixel_values)
                image_embeddings = image_embeddings / image_embeddings.norm(dim=-1, keepdim=True)
                image_embeddings_list.append(image_embeddings)

            image_embeddings = torch.cat(image_embeddings_list, dim=0)
            similarities = torch.matmul(text_embeddings, image_embeddings.T)
            similarities = similarities.squeeze(0)

            ranked_indices = torch.argsort(similarities, descending=True)

            if ranked_indices[0] == 0:
                correct_top1 += 1
            if 0 in ranked_indices[:2]:
                correct_top2 += 1

            total += 1

    top1_accuracy = correct_top1 / total * 100
    top2_accuracy = correct_top2 / total * 100
    return top1_accuracy, top2_accuracy

top1_accuracy, top2_accuracy = calculate_top1_and_top2_accuracy()
print(f"Top-1 Accuracy on Test Data: {top1_accuracy:.2f}%")
print(f"Top-2 Accuracy on Test Data: {top2_accuracy:.2f}%")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Evaluating on Test Data: 100%|██████████| 15/15 [00:03<00:00,  4.56it/s]
# Top-1 Accuracy on Test Data: 13.33%
# Top-2 Accuracy on Test Data: 40.00%
